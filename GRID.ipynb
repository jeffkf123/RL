# %%
import numpy as np

class Gridworld:
    def __init__(self, width, height, start, goal, obstacles=None, rewards=None):
        self.width = width
        self.height = height
        self.start = start
        self.goal = goal
        self.obstacles = obstacles if obstacles else []
        self.rewards = rewards if rewards else {}
        self.state = start
        self.actions = ['up', 'down', 'left', 'right']
    
    def move(self, action):
        if action == 'up':
            next_state = (max(self.state[0] - 1, 0), self.state[1])
        elif action == 'down':
            next_state = (min(self.state[0] + 1, self.height - 1), self.state[1])
        elif action == 'left':
            next_state = (self.state[0], max(self.state[1] - 1, 0))
        elif action == 'right':
            next_state = (self.state[0], min(self.state[1] + 1, self.width - 1))
        
        if next_state in self.obstacles:
            next_state = self.state  # No move if next state is an obstacle
        
        self.state = next_state
        return self.state, self.rewards.get(self.state, 0)  # Return next state and reward
    
    def is_goal_reached(self):
        return self.state == self.goal
    
    def reset(self):
        self.state = self.start
        return self.state

# %%
import numpy as np
class Gridworld:
    

    def __init__(self, width, height, start, goal, obstacles=None, rewards=None):
        self.width = width
        self.height = height
        self.start = start
        self.goal = goal
        self.obstacles = obstacles if obstacles else []
        self.rewards = rewards if rewards else {}
        self.state = start
        self.actions = ['up', 'down', 'left', 'right']
    
    def move(self, action):
    
        obstacle_hit_reward = -10

        if action == 'up':
            next_state = (max(self.state[0] - 1, 0), self.state[1])
        elif action == 'down':
            next_state = (min(self.state[0] + 1, self.height - 1), self.state[1])
        elif action == 'left':
            next_state = (self.state[0], max(self.state[1] - 1, 0))
        elif action == 'right':
            next_state = (self.state[0], min(self.state[1] + 1, self.width - 1))
        
        if next_state in self.obstacles:
            return self.state, obstacle_hit_reward
        
        # No obstacle
        self.state = next_state
        return self.state, self.rewards.get(self.state, 0)
    
    def is_goal_reached(self):
        return self.state == self.goal
    
    def reset(self):
        self.state = self.start
        return self.state

# %%
""" gridworld = Gridworld(width=5, height=5, start=(0, 0), goal=(4, 4), obstacles=[(1,2),(2, 2), (3,2), (4,1)], rewards={(4, 4): 10, (2, 2): -1})


def display_grid(state, width, height, goal, obstacles, clear_output=True):
    if clear_output:
        from IPython.display import clear_output
        clear_output(wait=True)
    
    grid = [[' ' for _ in range(width)] for _ in range(height)]
    for obstacle in obstacles:
        grid[obstacle[0]][obstacle[1]] = 'X'  # Mark obstacles
    grid[goal[0]][goal[1]] = 'G'  # Mark goal
    grid[state[0]][state[1]] = 'A'  # Mark agent's current position
    for row in grid[::-1]:  # Print from top to bottom
        print(' '.join(row))
    print("\n")



start_state = gridworld.reset()
print("Start State: ", start_state)
display_grid(start_state, gridworld.width, gridworld.height, gridworld.goal, gridworld.obstacles)

# Test 
actions = ['right', 'left']
for action in actions:
    next_state, reward = gridworld.move(action)
    print(f"Action: {action}, Next State: {next_state}, Reward: {reward}")
    display_grid(next_state, gridworld.width, gridworld.height, gridworld.goal, gridworld.obstacles)
    if gridworld.is_goal_reached():
        print("Goal Reached!")
        break
 """
# Out:
# ' gridworld = Gridworld(width=5, height=5, start=(0, 0), goal=(4, 4), obstacles=[(1,2),(2, 2), (3,2), (4,1)], rewards={(4, 4): 10, (2, 2): -1})\n\n\ndef display_grid(state, width, height, goal, obstacles, clear_output=True):\n    if clear_output:\n        from IPython.display import clear_output\n        clear_output(wait=True)\n    \n    grid = [[\' \' for _ in range(width)] for _ in range(height)]\n    for obstacle in obstacles:\n        grid[obstacle[0]][obstacle[1]] = \'X\'  # Mark obstacles\n    grid[goal[0]][goal[1]] = \'G\'  # Mark goal\n    grid[state[0]][state[1]] = \'A\'  # Mark agent\'s current position\n    for row in grid[::-1]:  # Print from top to bottom\n        print(\' \'.join(row))\n    print("\n")\n\n\n\nstart_state = gridworld.reset()\nprint("Start State: ", start_state)\ndisplay_grid(start_state, gridworld.width, gridworld.height, gridworld.goal, gridworld.obstacles)\n\n# Test \nactions = [\'right\', \'left\']\nfor action in actions:\n    next_state, reward = gridworld.move(action)\n    print(f"Action: {action}, Next State: {next_state}, Reward: {reward}")\n    display_grid(next_state, gridworld.width, gridworld.height, gridworld.goal, gridworld.obstacles)\n    if gridworld.is_goal_reached():\n        print("Goal Reached!")\n        break\n '

# %%
import numpy as np
obstacle_hit_reward = -10
class Gridworld:
    

    def __init__(self, width, height, start, goal, obstacles=None, rewards=None):
        self.width = width
        self.height = height
        self.start = start
        self.goal = goal
        self.obstacles = obstacles if obstacles else []
        self.rewards = rewards if rewards else {}
        self.state = start
        self.actions = ['up', 'down', 'left', 'right']
    
    def move(self, action):
        obstacle_hit_reward = -10

        if action == 'up':
            next_state = (max(self.state[0] - 1, 0), self.state[1])
        elif action == 'down':
            next_state = (min(self.state[0] + 1, self.height - 1), self.state[1])
        elif action == 'left':
            next_state = (self.state[0], max(self.state[1] - 1, 0))
        elif action == 'right':
            next_state = (self.state[0], min(self.state[1] + 1, self.width - 1))
        
        if next_state in self.obstacles:

            return self.state, obstacle_hit_reward
        
        self.state = next_state
        return self.state, self.rewards.get(self.state, 0)
    
    def is_goal_reached(self):
        return self.state == self.goal
    
    def reset(self):
        self.state = self.start
        return self.state

# %%
# Out:
# Episode 1 ended after 13 steps due to obstacle.
# Episode 1 ended after 71 steps due to obstacle.
# Episode 2 ended after 32 steps due to obstacle.
# Episode 3 ended after 41 steps due to obstacle.
# Episode 6 ended after 81 steps due to obstacle.
# Episode 6 ended after 97 steps due to obstacle.
# Episode 112 ended after 5 steps due to obstacle.
# Episode 126 ended after 5 steps due to obstacle.
# Episode 587 ended after 5 steps due to obstacle.
# Episode 689 ended after 5 steps due to obstacle.
# Episode 699 ended after 4 steps due to obstacle.
# Episode 717 ended after 5 steps due to obstacle.
# Episode 867 ended after 5 steps due to obstacle.
# Average reward per thousand episodes
#
# 1000 :  9.81

# %%
def display_grid(state, width, height, goal, obstacles, should_clear_output=True):
    if should_clear_output:
        clear_output(wait=True)
    
    grid = [[' ' for _ in range(width)] for _ in range(height)]
    for obstacle in obstacles:
        grid[obstacle[0]][obstacle[1]] = 'X'
    grid[goal[0]][goal[1]] = 'G'
    grid[state[0]][state[1]] = 'A'
    for row in grid[::-1]:
        print(' '.join(row))
    print("\n")
#TEXT GRID

# %%
run_simulation_with_visualization(gridworld, agent, num_episodes=100, visualize_every_n_episodes=20)
# Out:
# Episode: 1, Steps taken: 10, Reward: 10

# %%
gridworld = Gridworld(
    width=8,
    height=8,
    start=(0, 0),
    goal=(7, 6),
    obstacles=[(2, 2), (3,2)],
    rewards={(7,6): 10} 
)

class QLearningAgent:
    def __init__(self, alpha, gamma, epsilon, actions):
        self.q_table = {}
        self.alpha = alpha
        self.gamma = gamma  
        self.epsilon = epsilon  
        self.actions = actions 

    def get_q_value(self, state, action):
        return self.q_table.get((state, action), 0.0)

    def choose_action(self, state):
        if np.random.uniform(0, 1) < self.epsilon:  
            return np.random.choice(self.actions)
        else:  # Exploit
            q_values = [self.get_q_value(state, action) for action in self.actions]
            max_q = max(q_values)
            actions_with_max_q = [self.actions[i] for i in range(len(self.actions)) if q_values[i] == max_q]
            return np.random.choice(actions_with_max_q)

    def learn(self, state, action, reward, next_state):
        current_q = self.get_q_value(state, action)
        max_next_q = max([self.get_q_value(next_state, a) for a in self.actions])
        new_q = current_q + self.alpha * (reward + self.gamma * max_next_q - current_q)
        self.q_table[(state, action)] = new_q


alpha = 0.4  
gamma = 0.99  
epsilon = 0.41  
agent = QLearningAgent(alpha, gamma, epsilon, gridworld.actions)



num_episodes = 1000  
max_steps_per_episode = 100 

rewards_all_episodes = []
# Training
for episode in range(num_episodes):
    state = gridworld.reset() 
    total_rewards = 0

    for step in range(max_steps_per_episode):
        action = agent.choose_action(state)  
        next_state, reward = gridworld.move(action)  

        if reward == obstacle_hit_reward:
            print(f"Episode {episode + 1} ended after {step + 1} steps due to obstacle.")
            

        agent.learn(state, action, reward, next_state) 
        state = next_state 
        total_rewards += reward 

        if gridworld.is_goal_reached(): 
            break

    rewards_all_episodes.append(total_rewards)  

rewards_per_thousand_episodes = np.split(np.array(rewards_all_episodes),num_episodes/1000)
count = 1000
print("Average reward per thousand episodes\n")
for r in rewards_per_thousand_episodes:
    print(count, ": ", str(sum(r)/1000))
    count += 1000

import pygame

WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
GREEN = (0, 255, 0)
GOLD = (255, 215, 0)
RED = (255, 0, 0)

CELL_SIZE = 60
GRID_WIDTH = gridworld.width * CELL_SIZE
GRID_HEIGHT = gridworld.height * CELL_SIZE

pygame.init()

def draw_grid(surface, obstacles, goal):
    for x in range(0, GRID_WIDTH, CELL_SIZE):
        for y in range(0, GRID_HEIGHT, CELL_SIZE):
            rect = pygame.Rect(x, y, CELL_SIZE, CELL_SIZE)
            pygame.draw.rect(surface, WHITE, rect, 1)

    for obstacle in obstacles:
        rect = pygame.Rect(obstacle[1]*CELL_SIZE, (gridworld.height - 1 - obstacle[0])*CELL_SIZE, CELL_SIZE, CELL_SIZE)
        pygame.draw.rect(surface, RED, rect)

    rect = pygame.Rect(goal[1]*CELL_SIZE, (gridworld.height - 1 - goal[0])*CELL_SIZE, CELL_SIZE, CELL_SIZE)
    pygame.draw.rect(surface, GOLD, rect)

def update_visualization(surface, state):
    surface.fill((0, 0, 0))

    draw_grid(surface, gridworld.obstacles, gridworld.goal)

    rect = pygame.Rect(state[1]*CELL_SIZE, (gridworld.height - 1 - state[0])*CELL_SIZE, CELL_SIZE, CELL_SIZE)
    pygame.draw.rect(surface, GREEN, rect)

    pygame.display.flip()

def run_simulation_with_visualization(gridworld, agent, num_episodes=100, visualize_every_n_episodes=20):
    surface = pygame.display.set_mode((GRID_WIDTH, GRID_HEIGHT))
    pygame.display.set_caption('Grid RL')

    for episode in range(num_episodes):
        state = gridworld.reset()
        done = False

        for step in range(100):
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    pygame.quit()
                    return

            action = agent.choose_action(state)
            next_state, reward = gridworld.move(action)
            agent.learn(state, action, reward, next_state)

            update_visualization(surface, state)

            pygame.time.delay(100)

            state = next_state
            done = gridworld.is_goal_reached()
            if done:
                break

        print(f"Episode: {episode + 1}, Steps taken: {step}, Reward: {reward}")

        pygame.time.delay(100)

    pygame.quit()

run_simulation_with_visualization(gridworld, agent, num_episodes=100, visualize_every_n_episodes=20)
# Out:
# Episode 1 ended after 8 steps due to obstacle.
# Episode 2 ended after 6 steps due to obstacle.
# Episode 3 ended after 26 steps due to obstacle.
# Episode 5 ended after 28 steps due to obstacle.
# Episode 5 ended after 46 steps due to obstacle.
# Episode 5 ended after 70 steps due to obstacle.
# Episode 7 ended after 8 steps due to obstacle.
# Episode 7 ended after 9 steps due to obstacle.
# Episode 8 ended after 10 steps due to obstacle.
# Episode 10 ended after 44 steps due to obstacle.
# Episode 13 ended after 6 steps due to obstacle.
# Episode 15 ended after 30 steps due to obstacle.
# Episode 15 ended after 31 steps due to obstacle.
# Episode 15 ended after 65 steps due to obstacle.
# Episode 17 ended after 28 steps due to obstacle.
# Episode 17 ended after 75 steps due to obstacle.
# Episode 19 ended after 73 steps due to obstacle.
# Episode 19 ended after 76 steps due to obstacle.
# Episode 19 ended after 80 steps due to obstacle.
# Episode 19 ended after 81 steps due to obstacle.
# Episode 21 ended after 70 steps due to obstacle.
# Episode 21 ended after 71 steps due to obstacle.
# Episode 21 ended after 72 steps due to obstacle.
# Episode 23 ended after 18 steps due to obstacle.
# Episode 24 ended after 23 steps due to obstacle.
# Episode 25 ended after 32 steps due to obstacle.
# Episode 25 ended after 78 steps due to obstacle.
# Episode 26 ended after 6 steps due to obstacle.
# Episode 27 ended after 31 steps due to obstacle.
# Episode 28 ended after 8 steps due to obstacle.
# Episode 31 ended after 36 steps due to obstacle.
# Episode 32 ended after 9 steps due to obstacle.
# Episode 33 ended after 13 steps due to obstacle.
# Episode 37 ended after 13 steps due to obstacle.
# Episode 42 ended after 15 steps due to obstacle.
# Episode 45 ended after 10 steps due to obstacle.
# Episode 45 ended after 14 steps due to obstacle.
# Episode 48 ended after 12 steps due to obstacle.
# Episode 48 ended after 13 steps due to obstacle.
# Episode 49 ended after 13 steps due to obstacle.
# Episode 53 ended after 16 steps due to obstacle.
# Episode 58 ended after 18 steps due to obstacle.
# Episode 58 ended after 20 steps due to obstacle.
# Episode 60 ended after 5 steps due to obstacle.
# Episode 60 ended after 9 steps due to obstacle.
# Episode 61 ended after 8 steps due to obstacle.
# Episode 61 ended after 10 steps due to obstacle.
# Episode 62 ended after 8 steps due to obstacle.
# Episode 66 ended after 6 steps due to obstacle.
# Episode 71 ended after 14 steps due to obstacle.
# Episode 72 ended after 6 steps due to obstacle.
# Episode 72 ended after 8 steps due to obstacle.
# Episode 73 ended after 8 steps due to obstacle.
# Episode 79 ended after 6 steps due to obstacle.
# Episode 80 ended after 6 steps due to obstacle.
# Episode 87 ended after 6 steps due to obstacle.
# Episode 91 ended after 17 steps due to obstacle.
# Episode 91 ended after 18 steps due to obstacle.
# Episode 97 ended after 6 steps due to obstacle.
# Episode 101 ended after 13 steps due to obstacle.
# Episode 103 ended after 6 steps due to obstacle.
# Episode 106 ended after 11 steps due to obstacle.
# Episode 110 ended after 8 steps due to obstacle.
# Episode 111 ended after 15 steps due to obstacle.
# Episode 114 ended after 15 steps due to obstacle.
# Episode 119 ended after 12 steps due to obstacle.
# Episode 119 ended after 13 steps due to obstacle.
# Episode 123 ended after 10 steps due to obstacle.
# Episode 129 ended after 9 steps due to obstacle.
# Episode 134 ended after 6 steps due to obstacle.
# Episode 137 ended after 10 steps due to obstacle.
# Episode 139 ended after 10 steps due to obstacle.
# Episode 140 ended after 4 steps due to obstacle.
# Episode 142 ended after 8 steps due to obstacle.
# Episode 142 ended after 25 steps due to obstacle.
# Episode 143 ended after 4 steps due to obstacle.
# Episode 148 ended after 61 steps due to obstacle.
# Episode 149 ended after 9 steps due to obstacle.
# Episode 151 ended after 10 steps due to obstacle.
# Episode 153 ended after 17 steps due to obstacle.
# Episode 156 ended after 11 steps due to obstacle.
# Episode 158 ended after 4 steps due to obstacle.
# Episode 158 ended after 5 steps due to obstacle.
# Episode 162 ended after 16 steps due to obstacle.
# Episode 163 ended after 5 steps due to obstacle.
# Episode 165 ended after 9 steps due to obstacle.
# Episode 165 ended after 11 steps due to obstacle.
# Episode 169 ended after 10 steps due to obstacle.
# Episode 170 ended after 8 steps due to obstacle.
# Episode 172 ended after 6 steps due to obstacle.
# Episode 173 ended after 6 steps due to obstacle.
# Episode 174 ended after 13 steps due to obstacle.
# Episode 174 ended after 14 steps due to obstacle.
# Episode 175 ended after 10 steps due to obstacle.
# Episode 176 ended after 6 steps due to obstacle.
# Episode 180 ended after 9 steps due to obstacle.
# Episode 182 ended after 17 steps due to obstacle.
# Episode 182 ended after 20 steps due to obstacle.
# Episode 183 ended after 6 steps due to obstacle.
# Episode 183 ended after 11 steps due to obstacle.
# Episode 183 ended after 12 steps due to obstacle.
# Episode 187 ended after 10 steps due to obstacle.
# Episode 188 ended after 8 steps due to obstacle.
# Episode 189 ended after 13 steps due to obstacle.
# Episode 190 ended after 11 steps due to obstacle.
# Episode 192 ended after 9 steps due to obstacle.
# Episode 192 ended after 12 steps due to obstacle.
# Episode 197 ended after 6 steps due to obstacle.
# Episode 198 ended after 6 steps due to obstacle.
# Episode 199 ended after 8 steps due to obstacle.
# Episode 204 ended after 4 steps due to obstacle.
# Episode 204 ended after 13 steps due to obstacle.
# Episode 206 ended after 7 steps due to obstacle.
# Episode 206 ended after 8 steps due to obstacle.
# Episode 209 ended after 11 steps due to obstacle.
# Episode 211 ended after 7 steps due to obstacle.
# Episode 213 ended after 9 steps due to obstacle.
# Episode 213 ended after 13 steps due to obstacle.
# Episode 214 ended after 8 steps due to obstacle.
# Episode 217 ended after 5 steps due to obstacle.
# Episode 217 ended after 16 steps due to obstacle.
# Episode 218 ended after 13 steps due to obstacle.
# Episode 218 ended after 15 steps due to obstacle.
# Episode 221 ended after 9 steps due to obstacle.
# Episode 223 ended after 7 steps due to obstacle.
# Episode 228 ended after 15 steps due to obstacle.
# Episode 229 ended after 13 steps due to obstacle.
# Episode 229 ended after 24 steps due to obstacle.
# Episode 234 ended after 14 steps due to obstacle.
# Episode 234 ended after 15 steps due to obstacle.
# Episode 234 ended after 16 steps due to obstacle.
# Episode 234 ended after 20 steps due to obstacle.
# Episode 235 ended after 8 steps due to obstacle.
# Episode 235 ended after 9 steps due to obstacle.
# Episode 237 ended after 8 steps due to obstacle.
# Episode 239 ended after 21 steps due to obstacle.
# Episode 240 ended after 7 steps due to obstacle.
# Episode 241 ended after 10 steps due to obstacle.
# Episode 241 ended after 11 steps due to obstacle.
# Episode 242 ended after 6 steps due to obstacle.
# Episode 247 ended after 9 steps due to obstacle.
# Episode 251 ended after 6 steps due to obstacle.
# Episode 252 ended after 6 steps due to obstacle.
# Episode 253 ended after 11 steps due to obstacle.
# Episode 255 ended after 17 steps due to obstacle.
# Episode 256 ended after 19 steps due to obstacle.
# Episode 256 ended after 20 steps due to obstacle.
# Episode 258 ended after 6 steps due to obstacle.
# Episode 259 ended after 10 steps due to obstacle.
# Episode 262 ended after 11 steps due to obstacle.
# Episode 262 ended after 13 steps due to obstacle.
# Episode 263 ended after 5 steps due to obstacle.
# Episode 265 ended after 4 steps due to obstacle.
# Episode 267 ended after 10 steps due to obstacle.
# Episode 270 ended after 14 steps due to obstacle.
# Episode 271 ended after 14 steps due to obstacle.
# Episode 271 ended after 15 steps due to obstacle.
# Episode 275 ended after 18 steps due to obstacle.
# Episode 277 ended after 11 steps due to obstacle.
# Episode 279 ended after 9 steps due to obstacle.
# Episode 279 ended after 10 steps due to obstacle.
# Episode 283 ended after 21 steps due to obstacle.
# Episode 285 ended after 9 steps due to obstacle.
# Episode 287 ended after 7 steps due to obstacle.
# Episode 292 ended after 12 steps due to obstacle.
# Episode 294 ended after 8 steps due to obstacle.
# Episode 295 ended after 16 steps due to obstacle.
# Episode 298 ended after 9 steps due to obstacle.
# Episode 302 ended after 7 steps due to obstacle.
# Episode 303 ended after 22 steps due to obstacle.
# Episode 304 ended after 11 steps due to obstacle.
# Episode 304 ended after 22 steps due to obstacle.
# Episode 305 ended after 4 steps due to obstacle.
# Episode 305 ended after 9 steps due to obstacle.
# Episode 305 ended after 18 steps due to obstacle.
# Episode 307 ended after 6 steps due to obstacle.
# Episode 308 ended after 4 steps due to obstacle.
# Episode 311 ended after 8 steps due to obstacle.
# Episode 311 ended after 9 steps due to obstacle.
# Episode 311 ended after 12 steps due to obstacle.
# Episode 313 ended after 8 steps due to obstacle.
# Episode 314 ended after 18 steps due to obstacle.
# Episode 314 ended after 19 steps due to obstacle.
# Episode 316 ended after 12 steps due to obstacle.
# Episode 317 ended after 11 steps due to obstacle.
# Episode 322 ended after 6 steps due to obstacle.
# Episode 324 ended after 4 steps due to obstacle.
# Episode 324 ended after 5 steps due to obstacle.
# Episode 325 ended after 8 steps due to obstacle.
# Episode 328 ended after 6 steps due to obstacle.
# Episode 330 ended after 4 steps due to obstacle.
# Episode 330 ended after 9 steps due to obstacle.
# Episode 332 ended after 16 steps due to obstacle.
# Episode 332 ended after 21 steps due to obstacle.
# Episode 332 ended after 22 steps due to obstacle.
# Episode 334 ended after 9 steps due to obstacle.
# Episode 336 ended after 6 steps due to obstacle.
# Episode 339 ended after 6 steps due to obstacle.
# Episode 342 ended after 8 steps due to obstacle.
# Episode 343 ended after 5 steps due to obstacle.
# Episode 344 ended after 6 steps due to obstacle.
# Episode 344 ended after 10 steps due to obstacle.
# Episode 346 ended after 14 steps due to obstacle.
# Episode 346 ended after 15 steps due to obstacle.
# Episode 346 ended after 16 steps due to obstacle.
# Episode 346 ended after 20 steps due to obstacle.
# Episode 352 ended after 4 steps due to obstacle.
# Episode 357 ended after 6 steps due to obstacle.
# Episode 357 ended after 15 steps due to obstacle.
# Episode 359 ended after 7 steps due to obstacle.
# Episode 360 ended after 6 steps due to obstacle.
# Episode 362 ended after 4 steps due to obstacle.
# Episode 365 ended after 10 steps due to obstacle.
# Episode 365 ended after 13 steps due to obstacle.
# Episode 368 ended after 11 steps due to obstacle.
# Episode 368 ended after 16 steps due to obstacle.
# Episode 368 ended after 46 steps due to obstacle.
# Episode 373 ended after 14 steps due to obstacle.
# Episode 374 ended after 6 steps due to obstacle.
# Episode 385 ended after 7 steps due to obstacle.
# Episode 395 ended after 10 steps due to obstacle.
# Episode 397 ended after 6 steps due to obstacle.
# Episode 397 ended after 7 steps due to obstacle.
# Episode 401 ended after 4 steps due to obstacle.
# Episode 403 ended after 4 steps due to obstacle.
# Episode 406 ended after 8 steps due to obstacle.
# Episode 410 ended after 6 steps due to obstacle.
# Episode 412 ended after 8 steps due to obstacle.
# Episode 412 ended after 9 steps due to obstacle.
# Episode 416 ended after 16 steps due to obstacle.
# Episode 417 ended after 13 steps due to obstacle.
# Episode 418 ended after 12 steps due to obstacle.
# Episode 422 ended after 17 steps due to obstacle.
# Episode 422 ended after 29 steps due to obstacle.
# Episode 425 ended after 7 steps due to obstacle.
# Episode 425 ended after 9 steps due to obstacle.
# Episode 426 ended after 9 steps due to obstacle.
# Episode 434 ended after 8 steps due to obstacle.
# Episode 434 ended after 26 steps due to obstacle.
# Episode 437 ended after 7 steps due to obstacle.
# Episode 438 ended after 8 steps due to obstacle.
# Episode 439 ended after 10 steps due to obstacle.
# Episode 444 ended after 16 steps due to obstacle.
# Episode 445 ended after 16 steps due to obstacle.
# Episode 446 ended after 8 steps due to obstacle.
# Episode 448 ended after 12 steps due to obstacle.
# Episode 449 ended after 11 steps due to obstacle.
# Episode 449 ended after 14 steps due to obstacle.
# Episode 451 ended after 11 steps due to obstacle.
# Episode 453 ended after 6 steps due to obstacle.
# Episode 459 ended after 10 steps due to obstacle.
# Episode 462 ended after 9 steps due to obstacle.
# Episode 462 ended after 10 steps due to obstacle.
# Episode 465 ended after 10 steps due to obstacle.
# Episode 465 ended after 13 steps due to obstacle.
# Episode 470 ended after 8 steps due to obstacle.
# Episode 475 ended after 12 steps due to obstacle.
# Episode 477 ended after 7 steps due to obstacle.
# Episode 479 ended after 9 steps due to obstacle.
# Episode 482 ended after 6 steps due to obstacle.
# Episode 493 ended after 8 steps due to obstacle.
# Episode 494 ended after 6 steps due to obstacle.
# Episode 495 ended after 12 steps due to obstacle.
# Episode 498 ended after 15 steps due to obstacle.
# Episode 508 ended after 4 steps due to obstacle.
# Episode 510 ended after 7 steps due to obstacle.
# Episode 511 ended after 5 steps due to obstacle.
# Episode 512 ended after 6 steps due to obstacle.
# Episode 512 ended after 7 steps due to obstacle.
# Episode 514 ended after 7 steps due to obstacle.
# Episode 526 ended after 19 steps due to obstacle.
# Episode 528 ended after 7 steps due to obstacle.
# Episode 529 ended after 8 steps due to obstacle.
# Episode 530 ended after 6 steps due to obstacle.
# Episode 531 ended after 10 steps due to obstacle.
# Episode 532 ended after 14 steps due to obstacle.
# Episode 533 ended after 12 steps due to obstacle.
# Episode 541 ended after 6 steps due to obstacle.
# Episode 541 ended after 8 steps due to obstacle.
# Episode 541 ended after 9 steps due to obstacle.
# Episode 544 ended after 12 steps due to obstacle.
# Episode 550 ended after 6 steps due to obstacle.
# Episode 550 ended after 8 steps due to obstacle.
# Episode 551 ended after 12 steps due to obstacle.
# Episode 552 ended after 7 steps due to obstacle.
# Episode 554 ended after 27 steps due to obstacle.
# Episode 555 ended after 5 steps due to obstacle.
# Episode 558 ended after 9 steps due to obstacle.
# Episode 561 ended after 7 steps due to obstacle.
# Episode 562 ended after 23 steps due to obstacle.
# Episode 567 ended after 14 steps due to obstacle.
# Episode 569 ended after 6 steps due to obstacle.
# Episode 571 ended after 8 steps due to obstacle.
# Episode 571 ended after 9 steps due to obstacle.
# Episode 573 ended after 9 steps due to obstacle.
# Episode 578 ended after 12 steps due to obstacle.
# Episode 578 ended after 16 steps due to obstacle.
# Episode 578 ended after 19 steps due to obstacle.
# Episode 584 ended after 4 steps due to obstacle.
# Episode 585 ended after 8 steps due to obstacle.
# Episode 590 ended after 8 steps due to obstacle.
# Episode 590 ended after 12 steps due to obstacle.
# Episode 592 ended after 7 steps due to obstacle.
# Episode 594 ended after 19 steps due to obstacle.
# Episode 596 ended after 5 steps due to obstacle.
# Episode 598 ended after 10 steps due to obstacle.
# Episode 600 ended after 11 steps due to obstacle.
# Episode 604 ended after 15 steps due to obstacle.
# Episode 609 ended after 12 steps due to obstacle.
# Episode 613 ended after 15 steps due to obstacle.
# Episode 613 ended after 16 steps due to obstacle.
# Episode 613 ended after 17 steps due to obstacle.
# Episode 613 ended after 18 steps due to obstacle.
# Episode 613 ended after 19 steps due to obstacle.
# Episode 616 ended after 13 steps due to obstacle.
# Episode 619 ended after 4 steps due to obstacle.
# Episode 619 ended after 5 steps due to obstacle.
# Episode 619 ended after 8 steps due to obstacle.
# Episode 620 ended after 15 steps due to obstacle.
# Episode 621 ended after 4 steps due to obstacle.
# Episode 623 ended after 6 steps due to obstacle.
# Episode 625 ended after 9 steps due to obstacle.
# Episode 625 ended after 10 steps due to obstacle.
# Episode 625 ended after 18 steps due to obstacle.
# Episode 626 ended after 5 steps due to obstacle.
# Episode 626 ended after 6 steps due to obstacle.
# Episode 629 ended after 14 steps due to obstacle.
# Episode 630 ended after 6 steps due to obstacle.
# Episode 631 ended after 11 steps due to obstacle.
# Episode 633 ended after 4 steps due to obstacle.
# Episode 633 ended after 5 steps due to obstacle.
# Episode 633 ended after 9 steps due to obstacle.
# Episode 635 ended after 8 steps due to obstacle.
# Episode 635 ended after 11 steps due to obstacle.
# Episode 636 ended after 5 steps due to obstacle.
# Episode 636 ended after 6 steps due to obstacle.
# Episode 637 ended after 9 steps due to obstacle.
# Episode 639 ended after 9 steps due to obstacle.
# Episode 640 ended after 6 steps due to obstacle.
# Episode 646 ended after 6 steps due to obstacle.
# Episode 651 ended after 4 steps due to obstacle.
# Episode 652 ended after 16 steps due to obstacle.
# Episode 653 ended after 11 steps due to obstacle.
# Episode 656 ended after 8 steps due to obstacle.
# Episode 657 ended after 7 steps due to obstacle.
# Episode 663 ended after 6 steps due to obstacle.
# Episode 667 ended after 7 steps due to obstacle.
# Episode 667 ended after 8 steps due to obstacle.
# Episode 670 ended after 8 steps due to obstacle.
# Episode 671 ended after 17 steps due to obstacle.
# Episode 671 ended after 18 steps due to obstacle.
# Episode 676 ended after 9 steps due to obstacle.
# Episode 679 ended after 6 steps due to obstacle.
# Episode 679 ended after 7 steps due to obstacle.
# Episode 680 ended after 6 steps due to obstacle.
# Episode 690 ended after 14 steps due to obstacle.
# Episode 693 ended after 6 steps due to obstacle.
# Episode 693 ended after 10 steps due to obstacle.
# Episode 703 ended after 14 steps due to obstacle.
# Episode 714 ended after 7 steps due to obstacle.
# Episode 718 ended after 6 steps due to obstacle.
# Episode 722 ended after 8 steps due to obstacle.
# Episode 722 ended after 11 steps due to obstacle.
# Episode 723 ended after 4 steps due to obstacle.
# Episode 723 ended after 7 steps due to obstacle.
# Episode 723 ended after 10 steps due to obstacle.
# Episode 723 ended after 13 steps due to obstacle.
# Episode 727 ended after 6 steps due to obstacle.
# Episode 727 ended after 7 steps due to obstacle.
# Episode 731 ended after 4 steps due to obstacle.
# Episode 743 ended after 11 steps due to obstacle.
# Episode 743 ended after 14 steps due to obstacle.
# Episode 745 ended after 10 steps due to obstacle.
# Episode 747 ended after 15 steps due to obstacle.
# Episode 752 ended after 6 steps due to obstacle.
# Episode 753 ended after 7 steps due to obstacle.
# Episode 753 ended after 13 steps due to obstacle.
# Episode 753 ended after 14 steps due to obstacle.
# Episode 754 ended after 8 steps due to obstacle.
# Episode 757 ended after 6 steps due to obstacle.
# Episode 763 ended after 21 steps due to obstacle.
# Episode 766 ended after 12 steps due to obstacle.
# Episode 769 ended after 4 steps due to obstacle.
# Episode 772 ended after 15 steps due to obstacle.
# Episode 775 ended after 5 steps due to obstacle.
# Episode 775 ended after 9 steps due to obstacle.
# Episode 775 ended after 15 steps due to obstacle.
# Episode 776 ended after 9 steps due to obstacle.
# Episode 784 ended after 10 steps due to obstacle.
# Episode 793 ended after 8 steps due to obstacle.
# Episode 797 ended after 21 steps due to obstacle.
# Episode 803 ended after 5 steps due to obstacle.
# Episode 807 ended after 9 steps due to obstacle.
# Episode 808 ended after 11 steps due to obstacle.
# Episode 808 ended after 16 steps due to obstacle.
# Episode 809 ended after 10 steps due to obstacle.
# Episode 809 ended after 12 steps due to obstacle.
# Episode 819 ended after 12 steps due to obstacle.
# Episode 819 ended after 13 steps due to obstacle.
# Episode 822 ended after 7 steps due to obstacle.
# Episode 825 ended after 7 steps due to obstacle.
# Episode 827 ended after 9 steps due to obstacle.
# Episode 827 ended after 10 steps due to obstacle.
# Episode 828 ended after 11 steps due to obstacle.
# Episode 831 ended after 8 steps due to obstacle.
# Episode 833 ended after 10 steps due to obstacle.
# Episode 834 ended after 6 steps due to obstacle.
# Episode 836 ended after 12 steps due to obstacle.
# Episode 837 ended after 8 steps due to obstacle.
# Episode 839 ended after 4 steps due to obstacle.
# Episode 843 ended after 7 steps due to obstacle.
# Episode 846 ended after 12 steps due to obstacle.
# Episode 848 ended after 6 steps due to obstacle.
# Episode 848 ended after 7 steps due to obstacle.
# Episode 849 ended after 5 steps due to obstacle.
# Episode 859 ended after 11 steps due to obstacle.
# Episode 859 ended after 12 steps due to obstacle.
# Episode 862 ended after 8 steps due to obstacle.
# Episode 862 ended after 10 steps due to obstacle.
# Episode 868 ended after 10 steps due to obstacle.
# Episode 870 ended after 4 steps due to obstacle.
# Episode 870 ended after 5 steps due to obstacle.
# Episode 870 ended after 6 steps due to obstacle.
# Episode 872 ended after 10 steps due to obstacle.
# Episode 878 ended after 12 steps due to obstacle.
# Episode 882 ended after 10 steps due to obstacle.
# Episode 886 ended after 7 steps due to obstacle.
# Episode 888 ended after 12 steps due to obstacle.
# Episode 890 ended after 13 steps due to obstacle.
# Episode 892 ended after 8 steps due to obstacle.
# Episode 893 ended after 10 steps due to obstacle.
# Episode 898 ended after 11 steps due to obstacle.
# Episode 902 ended after 6 steps due to obstacle.
# Episode 902 ended after 7 steps due to obstacle.
# Episode 905 ended after 15 steps due to obstacle.
# Episode 907 ended after 7 steps due to obstacle.
# Episode 908 ended after 9 steps due to obstacle.
# Episode 908 ended after 20 steps due to obstacle.
# Episode 908 ended after 21 steps due to obstacle.
# Episode 909 ended after 11 steps due to obstacle.
# Episode 910 ended after 6 steps due to obstacle.
# Episode 912 ended after 5 steps due to obstacle.
# Episode 912 ended after 7 steps due to obstacle.
# Episode 914 ended after 5 steps due to obstacle.
# Episode 917 ended after 7 steps due to obstacle.
# Episode 918 ended after 7 steps due to obstacle.
# Episode 921 ended after 8 steps due to obstacle.
# Episode 933 ended after 6 steps due to obstacle.
# Episode 933 ended after 11 steps due to obstacle.
# Episode 938 ended after 4 steps due to obstacle.
# Episode 944 ended after 21 steps due to obstacle.
# Episode 950 ended after 4 steps due to obstacle.
# Episode 954 ended after 5 steps due to obstacle.
# Episode 954 ended after 15 steps due to obstacle.
# Episode 954 ended after 38 steps due to obstacle.
# Episode 957 ended after 9 steps due to obstacle.
# Episode 959 ended after 10 steps due to obstacle.
# Episode 961 ended after 7 steps due to obstacle.
# Episode 968 ended after 8 steps due to obstacle.
# Episode 971 ended after 6 steps due to obstacle.
# Episode 976 ended after 6 steps due to obstacle.
# Episode 977 ended after 12 steps due to obstacle.
# Episode 979 ended after 10 steps due to obstacle.
# Episode 980 ended after 5 steps due to obstacle.
# Episode 981 ended after 8 steps due to obstacle.
# Episode 982 ended after 4 steps due to obstacle.
# Episode 983 ended after 14 steps due to obstacle.
# Episode 983 ended after 17 steps due to obstacle.
# Episode 987 ended after 6 steps due to obstacle.
# Episode 991 ended after 6 steps due to obstacle.
# Episode 992 ended after 4 steps due to obstacle.
# Episode 995 ended after 10 steps due to obstacle.
# Episode 997 ended after 6 steps due to obstacle.
# Episode 1000 ended after 15 steps due to obstacle.
# Episode 1000 ended after 19 steps due to obstacle.
# Average reward per thousand episodes
#
# 1000 :  5.1
# Episode: 1, Steps taken: 20, Reward: 10
# Episode: 2, Steps taken: 26, Reward: 10
# Episode: 3, Steps taken: 32, Reward: 10
# Episode: 4, Steps taken: 14, Reward: 10
# Episode: 5, Steps taken: 14, Reward: 10
